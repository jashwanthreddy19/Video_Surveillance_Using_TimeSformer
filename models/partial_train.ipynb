# %%
import os
import sys
import torch
import torch.nn as nn
import torch.optim as optim
from torch import amp 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import confusion_matrix
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import ReduceLROnPlateau
sys.path.append(r"C:\Users\jashw\Desktop\Video Surveillance")
from datasets.custom_dataset import get_data_loader  # Your custom dataset loader
from TimeSformer.timesformer.models.vit import TimeSformer  # Import TimeSformer class


# -------------------
# Hyperparameters and Paths
# -------------------
MODEL_PATH = r"C:\Users\jashw\Desktop\Video Surveillance\data\trained_models\TimeSformer_divST_96x4_224_K600.pyth"
TRAIN_DIR = r"C:\Users\jashw\Desktop\Video Surveillance\data\train"  # Training dataset directory
VAL_DIR = r"C:\Users\jashw\Desktop\Video Surveillance\data\val"
BATCH_SIZE = 6
NUM_EPOCHS = 5
LEARNING_RATE = 1e-4
NUM_CLASSES = 8  # Target classes for your use-case


# -------------------
# Function to load the pretrained TimeSformer model
# -------------------
def load_model(pretrained_path, device):
    print(f"Loading pre-trained model from: {pretrained_path}")
    
    # Initialize model with num_classes=600 to match checkpoint
    model = TimeSformer(
        img_size=224,
        num_classes=600,
        num_frames=96,
        attention_type='divided_space_time',
        pretrained_model=pretrained_path  # This prevents external download if file exists
    )
    
    # Load checkpoint (checkpoint has keys: ['epoch', 'model_state', 'optimizer_state', 'cfg'])
    checkpoint = torch.load(pretrained_path, map_location=device)
    # Use 'model_state' since that's the key containing the weights
    model_state = checkpoint.get('model_state', checkpoint)
    # Load all weights except the classifier head (which are for 600 classes)
    model_state = {k: v for k, v in model_state.items() if not k.startswith("head")}
    model.load_state_dict(model_state, strict=False)
    
    model.to(device)
    print("Model loaded successfully!")
    return model


# -------------------
# Function to modify model for partial fine-tuning
# -------------------
def modify_for_partial_training(model, device, num_classes=8, freeze_layers=True):
    # Replace the classifier head with a new one for the target number of classes
    in_features = model.model.head.in_features
    model.model.head = nn.Linear(in_features, num_classes).to(device)

    
    # Freeze all parameters except those in the new classifier head
    if freeze_layers:
        for name, param in model.named_parameters():
            if "model.head" not in name:
                param.requires_grad = False

                
    print("Model modified for partial fine-tuning (only classifier head will be trained).")
    return model


# -------------------
# Training and Validation Functions
# -------------------
from torch.optim.lr_scheduler import ReduceLROnPlateau

def train_partial(
    model, train_loader, val_loader, device,
    epochs=NUM_EPOCHS,
    lr=LEARNING_RATE,
    target_accuracy=95.0,
    checkpoint_dir="checkpoints",
    log_dir="runs/TimeSformer",
    class_list = class_list
    
):
    os.makedirs(checkpoint_dir, exist_ok=True)
    writer = SummaryWriter(log_dir=log_dir)
    class_list = class_list
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.model.head.parameters(), lr=lr)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)
    scaler = amp.GradScaler()
    
    training_loss = []
    training_acc = []
    validation_loss = []
    val_acc = []
    
    best_accuracy = 0.0

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            print("Input shape to model:", inputs.shape)
            with amp.autocast('cuda'):
                outputs = model(inputs)
                loss = criterion(outputs, labels)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)

        val_loss, val_accuracy = validate(
            model, val_loader, device,
            writer=writer,
            epoch=epoch,
            class_names=class_list
        )

        training_loss.append(avg_loss)
        validation_loss.append(val_loss)
        val_acc.append(val_accuracy)
        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {avg_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%")

        # 🟢 TensorBoard Logging
        writer.add_scalar("Loss/train", avg_loss, epoch)
        writer.add_scalar("LearningRate", optimizer.param_groups[0]['lr'], epoch)

        # 🧠 Step the LR scheduler
        scheduler.step(val_loss)

        # 🏁 Save if better
        if val_accuracy > best_accuracy:
            best_accuracy = val_accuracy
            best_model_path = os.path.join(checkpoint_dir, f"best_model_epoch{epoch+1}_acc{val_accuracy:.2f}.pth")
            torch.save(model.state_dict(), best_model_path)
            print(f"✅ Saved better model at {best_model_path}")

        if val_accuracy >= target_accuracy:
            print(f"🎯 Target accuracy of {target_accuracy}% reached. Stopping training early.")
            break

    writer.close()
    print("Training complete!")


def plot_confusion_matrix(cm, class_names, normalize=False, title="Confusion Matrix"):
    if normalize:
        cm = cm.astype("float") / cm.sum(axis=1, keepdims=True)
        fmt = ".2f"
    else:
        fmt = "d"

    fig, ax = plt.subplots(figsize=(10, 8))
    sns.heatmap(
        cm,
        annot=True,
        fmt=fmt,
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names,
        square=True,
        linewidths=0.5,
        cbar=True
    )

    ax.set_xlabel("Predicted Labels", fontsize=12)
    ax.set_ylabel("True Labels", fontsize=12)
    ax.set_title(title, fontsize=14)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    return fig
def validate(model, val_loader, device, writer=None, epoch=None, class_names=None):
    model.eval()
    total = 0
    correct = 0
    running_val_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total if total > 0 else 0
    print(f"\n✅ Validation Accuracy: {accuracy:.2f}%")

    # ➕ Confusion Matrix
    if writer is not None and epoch is not None and class_names is not None:
        cm = confusion_matrix(all_labels, all_preds)

        # Raw Confusion Matrix
        raw_fig = plot_confusion_matrix(cm, class_names, normalize=False, title="Confusion Matrix (Raw Counts)")
        writer.add_figure("ConfusionMatrix/Raw", raw_fig, global_step=epoch)

        # Normalized Confusion Matrix
        norm_fig = plot_confusion_matrix(cm, class_names, normalize=True, title="Confusion Matrix (Normalized)")
        writer.add_figure("ConfusionMatrix/Normalized", norm_fig, global_step=epoch)

        # ➕ Classification Report
        report_str = classification_report(all_labels, all_preds, target_names=class_names)
        print(f"\n📊 Classification Report (Epoch {epoch}):\n{report_str}")

        # Log the text report as TensorBoard text
        writer.add_text("ClassificationReport", f"```\n{report_str}\n```", global_step=epoch)

    torch.cuda.empty_cache()
    return accuracy

# -------------------
# Main Function
# -------------------
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    # Load the pretrained model (with 600 classes) from the checkpoint
    model = load_model(MODEL_PATH, device)
    print(model)
    # Modify the model for your 8-class use case and freeze early layers for partial fine-tuning
    model = modify_for_partial_training(model, device, num_classes=NUM_CLASSES, freeze_layers=True)
    print(model)
    
    # Load training and validation data using your custom DataLoader
    train_loader = get_data_loader(TRAIN_DIR, batch_size=BATCH_SIZE, clip_len=96, shuffle=True)
    val_loader = get_data_loader(VAL_DIR, batch_size=BATCH_SIZE, clip_len=96, shuffle=False)
    
    # Optionally, compute class weights if needed for imbalanced data and integrate with CrossEntropyLoss
    
    class_list = ['Abuse', 'Explosion', 'Fighting', 'RoadAccidents', 'Robbery', 'Shooting', 'Vandalism', 'z_Normal_Videos_event']
    
    # Train the model partially (only the classifier head will be updated)
    train_partial(
    model, 
    train_loader, 
    val_loader, 
    device, 
    epochs=NUM_EPOCHS, 
    lr=LEARNING_RATE,
    target_accuracy=96.0,
    checkpoint_dir="data/trained_models/checkpoints",
    log_dir="runs/TimeSformer",
    class_list=class_list
    )

    
    # Save the fine-tuned model
    save_path = r"data\trained_models\timesformer_partial_finetuned.pth"
    torch.save(model.state_dict(), save_path)
    print(f"Partially fine-tuned model saved to {save_path}")


if __name__ == "__main__":
    main()

# %%
import os
import sys
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch import amp 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import ReduceLROnPlateau

# Append project root to sys.path if needed
sys.path.append(r"C:\Users\jashw\Desktop\Video Surveillance")
from datasets.custom_dataset import get_data_loader  # Your custom dataset loader
from TimeSformer.timesformer.models.vit import TimeSformer  # Import TimeSformer class

# -------------------
# Hyperparameters and Paths
# -------------------
MODEL_PATH = r"C:\Users\jashw\Desktop\Video Surveillance\data\trained_models\TimeSformer_divST_96x4_224_K600.pyth"
TRAIN_DIR = r"C:\Users\jashw\Desktop\Video Surveillance\data\train"  # Training dataset directory
VAL_DIR = r"C:\Users\jashw\Desktop\Video Surveillance\data\val"
BATCH_SIZE = 1
NUM_EPOCHS = 50
LEARNING_RATE = 1e-4
NUM_CLASSES = 8  # Target classes for your use-case

# Define actual class names (order must match your dataset labels)
CLASS_NAMES = ['Abuse', 'Explosion', 'Fighting', 'RoadAccidents', 'Robbery', 'Shooting', 'Vandalism', 'z_Normal_Videos_event']

# -------------------
# Function to load the pretrained TimeSformer model
# -------------------
def load_model(pretrained_path, device):
    print(f"Loading pre-trained model from: {pretrained_path}")
    
    # Initialize model with num_classes=600 to match checkpoint
    model = TimeSformer(
        img_size=224,
        num_classes=600,
        num_frames=96,
        attention_type='divided_space_time',
        pretrained_model=pretrained_path  # Prevents external download if file exists
    )
    
    # Load checkpoint (checkpoint has keys: ['epoch', 'model_state', 'optimizer_state', 'cfg'])
    checkpoint = torch.load(pretrained_path, map_location=device)
    # Use 'model_state' since that's the key containing the weights
    model_state = checkpoint.get('model_state', checkpoint)
    # Load all weights except the classifier head (which are for 600 classes)
    model_state = {k: v for k, v in model_state.items() if not k.startswith("head")}
    model.load_state_dict(model_state, strict=False)
    
    model.to(device)
    print("Model loaded successfully!")
    return model

# -------------------
# Function to modify model for partial fine-tuning
# -------------------
def modify_for_partial_training(model, device, num_classes=8, freeze_layers=True):
    # Replace the classifier head with a new one for the target number of classes
    in_features = model.model.head.in_features
    model.model.head = nn.Linear(in_features, num_classes).to(device)
    
    # Freeze all parameters except those in the new classifier head
    if freeze_layers:
        for name, param in model.named_parameters():
            if "model.head" not in name:
                param.requires_grad = False
                
    print("Model modified for partial fine-tuning (only classifier head will be trained).")
    return model

# -------------------
# Helper function to plot confusion matrix
# -------------------
def plot_confusion_matrix(cm, class_names, normalize=False, title="Confusion Matrix"):
    if normalize:
        cm = cm.astype("float") / cm.sum(axis=1, keepdims=True)
        fmt = ".2f"
    else:
        fmt = "d"

    fig, ax = plt.subplots(figsize=(10, 8))
    sns.heatmap(
        cm,
        annot=True,
        fmt=fmt,
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names,
        square=True,
        linewidths=0.5,
        cbar=True
    )

    ax.set_xlabel("Predicted Labels", fontsize=12)
    ax.set_ylabel("True Labels", fontsize=12)
    ax.set_title(title, fontsize=14)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    return fig

# -------------------
# Validation Function with logging and classification report
# -------------------
def validate(model, val_loader, device, writer=None, epoch=None, class_names=None):
    model.eval()
    total = 0
    correct = 0
    all_preds = []
    all_labels = []
    running_val_loss = 0.0
    criterion = nn.CrossEntropyLoss()

    print("Validating The Model....")
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_val_loss = running_val_loss / len(val_loader)
    accuracy = 100 * correct / total if total > 0 else 0
    print(f"\n✅ Validation Loss: {avg_val_loss:.4f} | Accuracy: {accuracy:.2f}%")

    # Log confusion matrix and classification report to TensorBoard
    if writer is not None and epoch is not None and class_names is not None:
        cm = confusion_matrix(all_labels, all_preds)

        # Raw Confusion Matrix
        raw_fig = plot_confusion_matrix(cm, class_names, normalize=False, title="Confusion Matrix (Raw Counts)")
        writer.add_figure("ConfusionMatrix/Raw", raw_fig, global_step=epoch)

        # Normalized Confusion Matrix
        norm_fig = plot_confusion_matrix(cm, class_names, normalize=True, title="Confusion Matrix (Normalized)")
        writer.add_figure("ConfusionMatrix/Normalized", norm_fig, global_step=epoch)

        # Classification Report
        report_str = classification_report(all_labels, all_preds, target_names=class_names)
        print(f"\n📊 Classification Report (Epoch {epoch}):\n{report_str}")
        writer.add_text("ClassificationReport", f"```\n{report_str}\n```", global_step=epoch)

        # Additionally log precision, recall, F1 scores per class
        precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds)
        for i, cname in enumerate(class_names):
            writer.add_scalar(f'Precision/{cname}', precision[i], epoch)
            writer.add_scalar(f'Recall/{cname}', recall[i], epoch)
            writer.add_scalar(f'F1-Score/{cname}', f1[i], epoch)

    torch.cuda.empty_cache()
    return avg_val_loss, accuracy

# -------------------
# Training Function with time measurement and estimated time remaining
# -------------------
def train_partial(
    model, train_loader, val_loader, device,
    epochs=NUM_EPOCHS,
    lr=LEARNING_RATE,
    target_accuracy=95.0,
    checkpoint_dir="checkpoints",
    log_dir="runs/TimeSformer",
    class_list=CLASS_NAMES
):
    os.makedirs(checkpoint_dir, exist_ok=True)
    writer = SummaryWriter(log_dir=log_dir)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.model.head.parameters(), lr=lr)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)
    scaler = amp.GradScaler()
    
    best_accuracy = 0.0
    total_start_time = time.time()
    epoch_times = []  # To store time per epoch for estimating remaining time

    for epoch in range(epochs):
        epoch_start_time = time.time()
        model.train()
        running_loss = 0.0
        i = BATCH_SIZE
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            print(f"In Epoch {epoch} Processed {i} videos remaining {1600 - i}")
            optimizer.zero_grad()
            with amp.autocast('cuda'):
                outputs = model(inputs)
                loss = criterion(outputs, labels)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            running_loss += loss.item()
            i += BATCH_SIZE
        
        avg_train_loss = running_loss / len(train_loader)
        epoch_train_time = time.time() - epoch_start_time
        epoch_times.append(epoch_train_time)

        # Validate and capture validation loss and accuracy
        val_loss, val_accuracy = validate(
            model, val_loader, device,
            writer=writer,
            epoch=epoch,
            class_names=class_list
        )

        epoch_total_time = time.time() - epoch_start_time

        # Estimate time remaining
        avg_epoch_time_so_far = np.mean(epoch_times)
        epochs_remaining = epochs - (epoch + 1)
        estimated_remaining_time = avg_epoch_time_so_far * epochs_remaining

        print(f"\n📦 Epoch [{epoch+1}/{epochs}] Summary:")
        print(f"🔺 Train Loss: {avg_train_loss:.4f} | Train Time: {epoch_train_time:.2f}s")
        print(f"🔹 Val Loss  : {val_loss:.4f} | Accuracy: {val_accuracy:.2f}%")
        print(f"⏱ Epoch Time: {epoch_total_time:.2f}s | Estimated Time Remaining: {estimated_remaining_time:.2f}s")
        
        # Log metrics to TensorBoard
        writer.add_scalar("Loss/train", avg_train_loss, epoch)
        writer.add_scalar("Loss/val", val_loss, epoch)
        writer.add_scalar("Accuracy/val", val_accuracy, epoch)
        writer.add_scalar("LearningRate", optimizer.param_groups[0]['lr'], epoch)
        writer.add_scalar("Epoch/Time", epoch_total_time, epoch)
        writer.add_scalar("EstimatedTimeRemaining", estimated_remaining_time, epoch)

        # Step the LR scheduler based on validation loss
        scheduler.step(val_loss)

        # Save checkpoint if improved accuracy
        if val_accuracy > best_accuracy:
            best_accuracy = val_accuracy
            best_model_path = os.path.join(checkpoint_dir, f"best_model_epoch{epoch+1}_acc{val_accuracy:.2f}.pth")
            torch.save(model.state_dict(), best_model_path)
            print(f"✅ Saved better model at {best_model_path}")

        if val_accuracy >= target_accuracy:
            print(f"🎯 Target accuracy of {target_accuracy}% reached. Stopping training early.")
            break

    total_training_time = time.time() - total_start_time
    writer.add_text("TrainingSummary", f"Total training time: {total_training_time:.2f}s", global_step=epochs)
    writer.close()
    print(f"\nTraining complete! Total time: {total_training_time:.2f} seconds.")

# -------------------
# Main Function
# -------------------
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    # Load the pretrained model (with 600 classes) from the checkpoint
    model = load_model(MODEL_PATH, device)
    
    # Modify the model for your 8-class use case and freeze early layers for partial fine-tuning
    model = modify_for_partial_training(model, device, num_classes=NUM_CLASSES, freeze_layers=True)
    
    # Load training and validation data using your custom DataLoader
    train_loader = get_data_loader(TRAIN_DIR, batch_size=BATCH_SIZE, clip_len=96, shuffle=True)
    val_loader = get_data_loader(VAL_DIR, batch_size=BATCH_SIZE, clip_len=96, shuffle=False)
    
    # Train the model partially (only the classifier head will be updated)
    train_partial(
        model, 
        train_loader, 
        val_loader, 
        device, 
        epochs=NUM_EPOCHS, 
        lr=LEARNING_RATE,
        target_accuracy=96.0,
        checkpoint_dir="data/trained_models/checkpoints",
        log_dir="runs/TimeSformer",
        class_list=CLASS_NAMES
    )
    
    # Save the final fine-tuned model
    save_path = r"data\trained_models\timesformer_partial_finetuned.pth"
    torch.save(model.state_dict(), save_path)
    print(f"Partially fine-tuned model saved to {save_path}")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Loading pre-trained model from: C:\Users\jashw\Desktop\Video Surveillance\data\trained_models\TimeSformer_divST_96x4_224_K600.pyth
# Model loaded successfully!
# Model modified for partial fine-tuning (only classifier head will be trained).
# c:\Users\jashw\Desktop\Video Surveillance\venv\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# In Epoch 0 Processed 1 videos remaining 1599
# In Epoch 0 Processed 2 videos remaining 1598
# In Epoch 0 Processed 3 videos remaining 1597
# In Epoch 0 Processed 4 videos remaining 1596
# In Epoch 0 Processed 5 videos remaining 1595
# In Epoch 0 Processed 6 videos remaining 1594
# In Epoch 0 Processed 7 videos remaining 1593
# In Epoch 0 Processed 8 videos remaining 1592
# In Epoch 0 Processed 9 videos remaining 1591
# In Epoch 0 Processed 10 videos remaining 1590
# In Epoch 0 Processed 11 videos remaining 1589
# In Epoch 0 Processed 12 videos remaining 1588
# In Epoch 0 Processed 13 videos remaining 1587
# In Epoch 0 Processed 14 videos remaining 1586
# In Epoch 0 Processed 15 videos remaining 1585
# In Epoch 0 Processed 16 videos remaining 1584
# In Epoch 0 Processed 17 videos remaining 1583
# In Epoch 0 Processed 18 videos remaining 1582
# In Epoch 0 Processed 19 videos remaining 1581
# In Epoch 0 Processed 20 videos remaining 1580
# In Epoch 0 Processed 21 videos remaining 1579
# In Epoch 0 Processed 22 videos remaining 1578
# In Epoch 0 Processed 23 videos remaining 1577
# In Epoch 0 Processed 24 videos remaining 1576
# In Epoch 0 Processed 25 videos remaining 1575
# In Epoch 0 Processed 26 videos remaining 1574
# In Epoch 0 Processed 27 videos remaining 1573
# In Epoch 0 Processed 28 videos remaining 1572
# In Epoch 0 Processed 29 videos remaining 1571
# In Epoch 0 Processed 30 videos remaining 1570
# In Epoch 0 Processed 31 videos remaining 1569
# In Epoch 0 Processed 32 videos remaining 1568
# In Epoch 0 Processed 33 videos remaining 1567
# In Epoch 0 Processed 34 videos remaining 1566
# In Epoch 0 Processed 35 videos remaining 1565
# In Epoch 0 Processed 36 videos remaining 1564
# In Epoch 0 Processed 37 videos remaining 1563
# In Epoch 0 Processed 38 videos remaining 1562
# In Epoch 0 Processed 39 videos remaining 1561
# In Epoch 0 Processed 40 videos remaining 1560
# In Epoch 0 Processed 41 videos remaining 1559
# In Epoch 0 Processed 42 videos remaining 1558
# In Epoch 0 Processed 43 videos remaining 1557
# In Epoch 0 Processed 44 videos remaining 1556
# In Epoch 0 Processed 45 videos remaining 1555
# In Epoch 0 Processed 46 videos remaining 1554
# In Epoch 0 Processed 47 videos remaining 1553
# In Epoch 0 Processed 48 videos remaining 1552
# In Epoch 0 Processed 49 videos remaining 1551
# In Epoch 0 Processed 50 videos remaining 1550
# In Epoch 0 Processed 51 videos remaining 1549
# In Epoch 0 Processed 52 videos remaining 1548
# In Epoch 0 Processed 53 videos remaining 1547
# In Epoch 0 Processed 54 videos remaining 1546
# In Epoch 0 Processed 55 videos remaining 1545
# In Epoch 0 Processed 56 videos remaining 1544
# In Epoch 0 Processed 57 videos remaining 1543
# In Epoch 0 Processed 58 videos remaining 1542
# In Epoch 0 Processed 59 videos remaining 1541
# In Epoch 0 Processed 60 videos remaining 1540
# In Epoch 0 Processed 61 videos remaining 1539
# In Epoch 0 Processed 62 videos remaining 1538
# In Epoch 0 Processed 63 videos remaining 1537
# In Epoch 0 Processed 64 videos remaining 1536
# In Epoch 0 Processed 65 videos remaining 1535
# In Epoch 0 Processed 66 videos remaining 1534
# In Epoch 0 Processed 67 videos remaining 1533
# In Epoch 0 Processed 68 videos remaining 1532
# In Epoch 0 Processed 69 videos remaining 1531
# In Epoch 0 Processed 70 videos remaining 1530
# In Epoch 0 Processed 71 videos remaining 1529
# In Epoch 0 Processed 72 videos remaining 1528
# In Epoch 0 Processed 73 videos remaining 1527
# In Epoch 0 Processed 74 videos remaining 1526
# In Epoch 0 Processed 75 videos remaining 1525
# In Epoch 0 Processed 76 videos remaining 1524
# In Epoch 0 Processed 77 videos remaining 1523
# In Epoch 0 Processed 78 videos remaining 1522
# In Epoch 0 Processed 79 videos remaining 1521
# In Epoch 0 Processed 80 videos remaining 1520
# In Epoch 0 Processed 81 videos remaining 1519
# In Epoch 0 Processed 82 videos remaining 1518
# In Epoch 0 Processed 83 videos remaining 1517
# In Epoch 0 Processed 84 videos remaining 1516
# In Epoch 0 Processed 85 videos remaining 1515
# In Epoch 0 Processed 86 videos remaining 1514
# In Epoch 0 Processed 87 videos remaining 1513
# In Epoch 0 Processed 88 videos remaining 1512
# In Epoch 0 Processed 89 videos remaining 1511
# In Epoch 0 Processed 90 videos remaining 1510
# In Epoch 0 Processed 91 videos remaining 1509
# In Epoch 0 Processed 92 videos remaining 1508
# In Epoch 0 Processed 93 videos remaining 1507
# In Epoch 0 Processed 94 videos remaining 1506
# In Epoch 0 Processed 95 videos remaining 1505
# In Epoch 0 Processed 96 videos remaining 1504
# In Epoch 0 Processed 97 videos remaining 1503
# In Epoch 0 Processed 98 videos remaining 1502
# In Epoch 0 Processed 99 videos remaining 1501
# In Epoch 0 Processed 100 videos remaining 1500
# In Epoch 0 Processed 101 videos remaining 1499
# In Epoch 0 Processed 102 videos remaining 1498
# In Epoch 0 Processed 103 videos remaining 1497
# In Epoch 0 Processed 104 videos remaining 1496
# In Epoch 0 Processed 105 videos remaining 1495
# In Epoch 0 Processed 106 videos remaining 1494
# In Epoch 0 Processed 107 videos remaining 1493
# In Epoch 0 Processed 108 videos remaining 1492
# In Epoch 0 Processed 109 videos remaining 1491
# In Epoch 0 Processed 110 videos remaining 1490
# In Epoch 0 Processed 111 videos remaining 1489
# In Epoch 0 Processed 112 videos remaining 1488
# In Epoch 0 Processed 113 videos remaining 1487
# In Epoch 0 Processed 114 videos remaining 1486
# In Epoch 0 Processed 115 videos remaining 1485
# In Epoch 0 Processed 116 videos remaining 1484
# In Epoch 0 Processed 117 videos remaining 1483
# In Epoch 0 Processed 118 videos remaining 1482
# In Epoch 0 Processed 119 videos remaining 1481
# In Epoch 0 Processed 120 videos remaining 1480
# In Epoch 0 Processed 121 videos remaining 1479
# In Epoch 0 Processed 122 videos remaining 1478
# In Epoch 0 Processed 123 videos remaining 1477
# In Epoch 0 Processed 124 videos remaining 1476
# In Epoch 0 Processed 125 videos remaining 1475
# In Epoch 0 Processed 126 videos remaining 1474
# In Epoch 0 Processed 127 videos remaining 1473
# In Epoch 0 Processed 128 videos remaining 1472
# In Epoch 0 Processed 129 videos remaining 1471
# In Epoch 0 Processed 130 videos remaining 1470
# In Epoch 0 Processed 131 videos remaining 1469
# In Epoch 0 Processed 132 videos remaining 1468
# In Epoch 0 Processed 133 videos remaining 1467
# In Epoch 0 Processed 134 videos remaining 1466
# In Epoch 0 Processed 135 videos remaining 1465
# In Epoch 0 Processed 136 videos remaining 1464
# In Epoch 0 Processed 137 videos remaining 1463
# In Epoch 0 Processed 138 videos remaining 1462
# In Epoch 0 Processed 139 videos remaining 1461
# In Epoch 0 Processed 140 videos remaining 1460
# In Epoch 0 Processed 141 videos remaining 1459
# In Epoch 0 Processed 142 videos remaining 1458
# In Epoch 0 Processed 143 videos remaining 1457
# In Epoch 0 Processed 144 videos remaining 1456
# In Epoch 0 Processed 145 videos remaining 1455
# In Epoch 0 Processed 146 videos remaining 1454
# In Epoch 0 Processed 147 videos remaining 1453
# In Epoch 0 Processed 148 videos remaining 1452
# In Epoch 0 Processed 149 videos remaining 1451
# In Epoch 0 Processed 150 videos remaining 1450
# In Epoch 0 Processed 151 videos remaining 1449
# In Epoch 0 Processed 152 videos remaining 1448
# In Epoch 0 Processed 153 videos remaining 1447
# In Epoch 0 Processed 154 videos remaining 1446
# In Epoch 0 Processed 155 videos remaining 1445
# In Epoch 0 Processed 156 videos remaining 1444
# In Epoch 0 Processed 157 videos remaining 1443
# In Epoch 0 Processed 158 videos remaining 1442
# In Epoch 0 Processed 159 videos remaining 1441
# In Epoch 0 Processed 160 videos remaining 1440
# In Epoch 0 Processed 161 videos remaining 1439
# In Epoch 0 Processed 162 videos remaining 1438
# In Epoch 0 Processed 163 videos remaining 1437
# In Epoch 0 Processed 164 videos remaining 1436
# In Epoch 0 Processed 165 videos remaining 1435
# In Epoch 0 Processed 166 videos remaining 1434
# In Epoch 0 Processed 167 videos remaining 1433
# In Epoch 0 Processed 168 videos remaining 1432
# In Epoch 0 Processed 169 videos remaining 1431
# In Epoch 0 Processed 170 videos remaining 1430
# In Epoch 0 Processed 171 videos remaining 1429
# In Epoch 0 Processed 172 videos remaining 1428
# In Epoch 0 Processed 173 videos remaining 1427
# In Epoch 0 Processed 174 videos remaining 1426
# In Epoch 0 Processed 175 videos remaining 1425
# In Epoch 0 Processed 176 videos remaining 1424
# In Epoch 0 Processed 177 videos remaining 1423
# In Epoch 0 Processed 178 videos remaining 1422
# In Epoch 0 Processed 179 videos remaining 1421
# In Epoch 0 Processed 180 videos remaining 1420
# In Epoch 0 Processed 181 videos remaining 1419
# In Epoch 0 Processed 182 videos remaining 1418
# In Epoch 0 Processed 183 videos remaining 1417
# In Epoch 0 Processed 184 videos remaining 1416
# In Epoch 0 Processed 185 videos remaining 1415
# In Epoch 0 Processed 186 videos remaining 1414
# In Epoch 0 Processed 187 videos remaining 1413
# In Epoch 0 Processed 188 videos remaining 1412
# In Epoch 0 Processed 189 videos remaining 1411
# In Epoch 0 Processed 190 videos remaining 1410
# In Epoch 0 Processed 191 videos remaining 1409
# In Epoch 0 Processed 192 videos remaining 1408
# In Epoch 0 Processed 193 videos remaining 1407
# In Epoch 0 Processed 194 videos remaining 1406
# In Epoch 0 Processed 195 videos remaining 1405
# In Epoch 0 Processed 196 videos remaining 1404
# In Epoch 0 Processed 197 videos remaining 1403
# In Epoch 0 Processed 198 videos remaining 1402
# In Epoch 0 Processed 199 videos remaining 1401
# In Epoch 0 Processed 200 videos remaining 1400
# In Epoch 0 Processed 201 videos remaining 1399
# In Epoch 0 Processed 202 videos remaining 1398
# In Epoch 0 Processed 203 videos remaining 1397
# In Epoch 0 Processed 204 videos remaining 1396
# In Epoch 0 Processed 205 videos remaining 1395
# In Epoch 0 Processed 206 videos remaining 1394
# In Epoch 0 Processed 207 videos remaining 1393
# In Epoch 0 Processed 208 videos remaining 1392
# In Epoch 0 Processed 209 videos remaining 1391
# In Epoch 0 Processed 210 videos remaining 1390
# In Epoch 0 Processed 211 videos remaining 1389
# In Epoch 0 Processed 212 videos remaining 1388
# In Epoch 0 Processed 213 videos remaining 1387
# In Epoch 0 Processed 214 videos remaining 1386
# In Epoch 0 Processed 215 videos remaining 1385
# In Epoch 0 Processed 216 videos remaining 1384
# In Epoch 0 Processed 217 videos remaining 1383
# In Epoch 0 Processed 218 videos remaining 1382
# In Epoch 0 Processed 219 videos remaining 1381
# In Epoch 0 Processed 220 videos remaining 1380
# In Epoch 0 Processed 221 videos remaining 1379
# In Epoch 0 Processed 222 videos remaining 1378
# In Epoch 0 Processed 223 videos remaining 1377
# In Epoch 0 Processed 224 videos remaining 1376
# In Epoch 0 Processed 225 videos remaining 1375
# In Epoch 0 Processed 226 videos remaining 1374
# In Epoch 0 Processed 227 videos remaining 1373
# In Epoch 0 Processed 228 videos remaining 1372
# In Epoch 0 Processed 229 videos remaining 1371
# In Epoch 0 Processed 230 videos remaining 1370
# In Epoch 0 Processed 231 videos remaining 1369
# In Epoch 0 Processed 232 videos remaining 1368
# In Epoch 0 Processed 233 videos remaining 1367
# In Epoch 0 Processed 234 videos remaining 1366
# In Epoch 0 Processed 235 videos remaining 1365
# In Epoch 0 Processed 236 videos remaining 1364
# In Epoch 0 Processed 237 videos remaining 1363
# In Epoch 0 Processed 238 videos remaining 1362
# In Epoch 0 Processed 239 videos remaining 1361
# In Epoch 0 Processed 240 videos remaining 1360
# In Epoch 0 Processed 241 videos remaining 1359
# In Epoch 0 Processed 242 videos remaining 1358
# In Epoch 0 Processed 243 videos remaining 1357
# In Epoch 0 Processed 244 videos remaining 1356
# In Epoch 0 Processed 245 videos remaining 1355
# In Epoch 0 Processed 246 videos remaining 1354
# In Epoch 0 Processed 247 videos remaining 1353
# In Epoch 0 Processed 248 videos remaining 1352
# In Epoch 0 Processed 249 videos remaining 1351
# In Epoch 0 Processed 250 videos remaining 1350
# In Epoch 0 Processed 251 videos remaining 1349
# In Epoch 0 Processed 252 videos remaining 1348
# In Epoch 0 Processed 253 videos remaining 1347
# In Epoch 0 Processed 254 videos remaining 1346
# In Epoch 0 Processed 255 videos remaining 1345
# In Epoch 0 Processed 256 videos remaining 1344
# In Epoch 0 Processed 257 videos remaining 1343
# In Epoch 0 Processed 258 videos remaining 1342
# In Epoch 0 Processed 259 videos remaining 1341
# In Epoch 0 Processed 260 videos remaining 1340
# In Epoch 0 Processed 261 videos remaining 1339
# In Epoch 0 Processed 262 videos remaining 1338
# In Epoch 0 Processed 263 videos remaining 1337
# In Epoch 0 Processed 264 videos remaining 1336
# In Epoch 0 Processed 265 videos remaining 1335
# In Epoch 0 Processed 266 videos remaining 1334
# In Epoch 0 Processed 267 videos remaining 1333
# In Epoch 0 Processed 268 videos remaining 1332
# In Epoch 0 Processed 269 videos remaining 1331
# In Epoch 0 Processed 270 videos remaining 1330
# In Epoch 0 Processed 271 videos remaining 1329
# In Epoch 0 Processed 272 videos remaining 1328
# In Epoch 0 Processed 273 videos remaining 1327
# In Epoch 0 Processed 274 videos remaining 1326
# In Epoch 0 Processed 275 videos remaining 1325
# In Epoch 0 Processed 276 videos remaining 1324
# In Epoch 0 Processed 277 videos remaining 1323
# In Epoch 0 Processed 278 videos remaining 1322
# In Epoch 0 Processed 279 videos remaining 1321
# In Epoch 0 Processed 280 videos remaining 1320
# In Epoch 0 Processed 281 videos remaining 1319
# In Epoch 0 Processed 282 videos remaining 1318
# In Epoch 0 Processed 283 videos remaining 1317
# In Epoch 0 Processed 284 videos remaining 1316
# In Epoch 0 Processed 285 videos remaining 1315
# In Epoch 0 Processed 286 videos remaining 1314
# In Epoch 0 Processed 287 videos remaining 1313
# In Epoch 0 Processed 288 videos remaining 1312
# In Epoch 0 Processed 289 videos remaining 1311
# In Epoch 0 Processed 290 videos remaining 1310
# In Epoch 0 Processed 291 videos remaining 1309
# In Epoch 0 Processed 292 videos remaining 1308
# In Epoch 0 Processed 293 videos remaining 1307
# In Epoch 0 Processed 294 videos remaining 1306
# In Epoch 0 Processed 295 videos remaining 1305
# In Epoch 0 Processed 296 videos remaining 1304
# In Epoch 0 Processed 297 videos remaining 1303
# In Epoch 0 Processed 298 videos remaining 1302
# In Epoch 0 Processed 299 videos remaining 1301
# In Epoch 0 Processed 300 videos remaining 1300
# In Epoch 0 Processed 301 videos remaining 1299
# In Epoch 0 Processed 302 videos remaining 1298
# In Epoch 0 Processed 303 videos remaining 1297
# In Epoch 0 Processed 304 videos remaining 1296
# In Epoch 0 Processed 305 videos remaining 1295
# In Epoch 0 Processed 306 videos remaining 1294
# In Epoch 0 Processed 307 videos remaining 1293
# In Epoch 0 Processed 308 videos remaining 1292
# In Epoch 0 Processed 309 videos remaining 1291
# In Epoch 0 Processed 310 videos remaining 1290
# In Epoch 0 Processed 311 videos remaining 1289
# In Epoch 0 Processed 312 videos remaining 1288
# In Epoch 0 Processed 313 videos remaining 1287
# In Epoch 0 Processed 314 videos remaining 1286
# In Epoch 0 Processed 315 videos remaining 1285
# In Epoch 0 Processed 316 videos remaining 1284
# In Epoch 0 Processed 317 videos remaining 1283
# In Epoch 0 Processed 318 videos remaining 1282
# In Epoch 0 Processed 319 videos remaining 1281
# In Epoch 0 Processed 320 videos remaining 1280
# In Epoch 0 Processed 321 videos remaining 1279
# In Epoch 0 Processed 322 videos remaining 1278
# In Epoch 0 Processed 323 videos remaining 1277
# In Epoch 0 Processed 324 videos remaining 1276
# In Epoch 0 Processed 325 videos remaining 1275
# In Epoch 0 Processed 326 videos remaining 1274
# In Epoch 0 Processed 327 videos remaining 1273
# In Epoch 0 Processed 328 videos remaining 1272
# In Epoch 0 Processed 329 videos remaining 1271
# In Epoch 0 Processed 330 videos remaining 1270
# In Epoch 0 Processed 331 videos remaining 1269
# In Epoch 0 Processed 332 videos remaining 1268
# In Epoch 0 Processed 333 videos remaining 1267
# In Epoch 0 Processed 334 videos remaining 1266
# In Epoch 0 Processed 335 videos remaining 1265
# In Epoch 0 Processed 336 videos remaining 1264
# In Epoch 0 Processed 337 videos remaining 1263
# In Epoch 0 Processed 338 videos remaining 1262
# In Epoch 0 Processed 339 videos remaining 1261
# In Epoch 0 Processed 340 videos remaining 1260
# In Epoch 0 Processed 341 videos remaining 1259
# In Epoch 0 Processed 342 videos remaining 1258
# In Epoch 0 Processed 343 videos remaining 1257
# In Epoch 0 Processed 344 videos remaining 1256
# In Epoch 0 Processed 345 videos remaining 1255
# In Epoch 0 Processed 346 videos remaining 1254
# In Epoch 0 Processed 347 videos remaining 1253
# In Epoch 0 Processed 348 videos remaining 1252
# In Epoch 0 Processed 349 videos remaining 1251
# In Epoch 0 Processed 350 videos remaining 1250
# In Epoch 0 Processed 351 videos remaining 1249
# In Epoch 0 Processed 352 videos remaining 1248
# In Epoch 0 Processed 353 videos remaining 1247
# In Epoch 0 Processed 354 videos remaining 1246
# In Epoch 0 Processed 355 videos remaining 1245
# In Epoch 0 Processed 356 videos remaining 1244
# In Epoch 0 Processed 357 videos remaining 1243
# In Epoch 0 Processed 358 videos remaining 1242
# In Epoch 0 Processed 359 videos remaining 1241
# In Epoch 0 Processed 360 videos remaining 1240
# In Epoch 0 Processed 361 videos remaining 1239
# In Epoch 0 Processed 362 videos remaining 1238
# In Epoch 0 Processed 363 videos remaining 1237
# In Epoch 0 Processed 364 videos remaining 1236
# In Epoch 0 Processed 365 videos remaining 1235
# In Epoch 0 Processed 366 videos remaining 1234
# In Epoch 0 Processed 367 videos remaining 1233
# In Epoch 0 Processed 368 videos remaining 1232
# In Epoch 0 Processed 369 videos remaining 1231
# In Epoch 0 Processed 370 videos remaining 1230
# In Epoch 0 Processed 371 videos remaining 1229
# In Epoch 0 Processed 372 videos remaining 1228
# In Epoch 0 Processed 373 videos remaining 1227
# In Epoch 0 Processed 374 videos remaining 1226
# In Epoch 0 Processed 375 videos remaining 1225
# In Epoch 0 Processed 376 videos remaining 1224
# In Epoch 0 Processed 377 videos remaining 1223
# In Epoch 0 Processed 378 videos remaining 1222
# In Epoch 0 Processed 379 videos remaining 1221
# In Epoch 0 Processed 380 videos remaining 1220
# In Epoch 0 Processed 381 videos remaining 1219
# In Epoch 0 Processed 382 videos remaining 1218
# In Epoch 0 Processed 383 videos remaining 1217
# In Epoch 0 Processed 384 videos remaining 1216
# In Epoch 0 Processed 385 videos remaining 1215
# In Epoch 0 Processed 386 videos remaining 1214
# In Epoch 0 Processed 387 videos remaining 1213
# In Epoch 0 Processed 388 videos remaining 1212
# In Epoch 0 Processed 389 videos remaining 1211
# In Epoch 0 Processed 390 videos remaining 1210
# In Epoch 0 Processed 391 videos remaining 1209
# In Epoch 0 Processed 392 videos remaining 1208
# In Epoch 0 Processed 393 videos remaining 1207
# In Epoch 0 Processed 394 videos remaining 1206
# In Epoch 0 Processed 395 videos remaining 1205
# In Epoch 0 Processed 396 videos remaining 1204
# In Epoch 0 Processed 397 videos remaining 1203
# In Epoch 0 Processed 398 videos remaining 1202
# In Epoch 0 Processed 399 videos remaining 1201
# In Epoch 0 Processed 400 videos remaining 1200
# In Epoch 0 Processed 401 videos remaining 1199
# In Epoch 0 Processed 402 videos remaining 1198
# In Epoch 0 Processed 403 videos remaining 1197
# In Epoch 0 Processed 404 videos remaining 1196
# In Epoch 0 Processed 405 videos remaining 1195
# In Epoch 0 Processed 406 videos remaining 1194
# In Epoch 0 Processed 407 videos remaining 1193
# In Epoch 0 Processed 408 videos remaining 1192
# In Epoch 0 Processed 409 videos remaining 1191
# In Epoch 0 Processed 410 videos remaining 1190
# In Epoch 0 Processed 411 videos remaining 1189
# In Epoch 0 Processed 412 videos remaining 1188
# In Epoch 0 Processed 413 videos remaining 1187
# In Epoch 0 Processed 414 videos remaining 1186
# In Epoch 0 Processed 415 videos remaining 1185
# In Epoch 0 Processed 416 videos remaining 1184
# In Epoch 0 Processed 417 videos remaining 1183
# In Epoch 0 Processed 418 videos remaining 1182
# In Epoch 0 Processed 419 videos remaining 1181
# In Epoch 0 Processed 420 videos remaining 1180
# In Epoch 0 Processed 421 videos remaining 1179
# In Epoch 0 Processed 422 videos remaining 1178
# In Epoch 0 Processed 423 videos remaining 1177
# In Epoch 0 Processed 424 videos remaining 1176
# In Epoch 0 Processed 425 videos remaining 1175
# In Epoch 0 Processed 426 videos remaining 1174
# In Epoch 0 Processed 427 videos remaining 1173
# In Epoch 0 Processed 428 videos remaining 1172
# In Epoch 0 Processed 429 videos remaining 1171
# In Epoch 0 Processed 430 videos remaining 1170
# In Epoch 0 Processed 431 videos remaining 1169
# In Epoch 0 Processed 432 videos remaining 1168
# In Epoch 0 Processed 433 videos remaining 1167
# In Epoch 0 Processed 434 videos remaining 1166
# In Epoch 0 Processed 435 videos remaining 1165
# In Epoch 0 Processed 436 videos remaining 1164
# In Epoch 0 Processed 437 videos remaining 1163
# In Epoch 0 Processed 438 videos remaining 1162
# In Epoch 0 Processed 439 videos remaining 1161
# In Epoch 0 Processed 440 videos remaining 1160
# In Epoch 0 Processed 441 videos remaining 1159
# In Epoch 0 Processed 442 videos remaining 1158
# In Epoch 0 Processed 443 videos remaining 1157
# In Epoch 0 Processed 444 videos remaining 1156
# In Epoch 0 Processed 445 videos remaining 1155
# In Epoch 0 Processed 446 videos remaining 1154
# In Epoch 0 Processed 447 videos remaining 1153
# In Epoch 0 Processed 448 videos remaining 1152
# In Epoch 0 Processed 449 videos remaining 1151
# In Epoch 0 Processed 450 videos remaining 1150
# In Epoch 0 Processed 451 videos remaining 1149
# In Epoch 0 Processed 452 videos remaining 1148
# In Epoch 0 Processed 453 videos remaining 1147
# In Epoch 0 Processed 454 videos remaining 1146
# In Epoch 0 Processed 455 videos remaining 1145
# In Epoch 0 Processed 456 videos remaining 1144
# In Epoch 0 Processed 457 videos remaining 1143
# In Epoch 0 Processed 458 videos remaining 1142
# In Epoch 0 Processed 459 videos remaining 1141
# In Epoch 0 Processed 460 videos remaining 1140
# In Epoch 0 Processed 461 videos remaining 1139
# In Epoch 0 Processed 462 videos remaining 1138
# In Epoch 0 Processed 463 videos remaining 1137
# In Epoch 0 Processed 464 videos remaining 1136
# In Epoch 0 Processed 465 videos remaining 1135
# In Epoch 0 Processed 466 videos remaining 1134
# In Epoch 0 Processed 467 videos remaining 1133
# In Epoch 0 Processed 468 videos remaining 1132
# In Epoch 0 Processed 469 videos remaining 1131
# In Epoch 0 Processed 470 videos remaining 1130
# In Epoch 0 Processed 471 videos remaining 1129
# In Epoch 0 Processed 472 videos remaining 1128
# In Epoch 0 Processed 473 videos remaining 1127
# In Epoch 0 Processed 474 videos remaining 1126
# In Epoch 0 Processed 475 videos remaining 1125
# In Epoch 0 Processed 476 videos remaining 1124
# In Epoch 0 Processed 477 videos remaining 1123
# In Epoch 0 Processed 478 videos remaining 1122
# In Epoch 0 Processed 479 videos remaining 1121
# In Epoch 0 Processed 480 videos remaining 1120
# In Epoch 0 Processed 481 videos remaining 1119
# In Epoch 0 Processed 482 videos remaining 1118
# In Epoch 0 Processed 483 videos remaining 1117
# In Epoch 0 Processed 484 videos remaining 1116
# In Epoch 0 Processed 485 videos remaining 1115
# In Epoch 0 Processed 486 videos remaining 1114
# In Epoch 0 Processed 487 videos remaining 1113
# In Epoch 0 Processed 488 videos remaining 1112
# In Epoch 0 Processed 489 videos remaining 1111
# In Epoch 0 Processed 490 videos remaining 1110
# In Epoch 0 Processed 491 videos remaining 1109
# In Epoch 0 Processed 492 videos remaining 1108
# In Epoch 0 Processed 493 videos remaining 1107
# In Epoch 0 Processed 494 videos remaining 1106
# In Epoch 0 Processed 495 videos remaining 1105
# In Epoch 0 Processed 496 videos remaining 1104
# In Epoch 0 Processed 497 videos remaining 1103
# In Epoch 0 Processed 498 videos remaining 1102
# In Epoch 0 Processed 499 videos remaining 1101
# In Epoch 0 Processed 500 videos remaining 1100
# In Epoch 0 Processed 501 videos remaining 1099
# In Epoch 0 Processed 502 videos remaining 1098
# In Epoch 0 Processed 503 videos remaining 1097
# In Epoch 0 Processed 504 videos remaining 1096
# In Epoch 0 Processed 505 videos remaining 1095
# In Epoch 0 Processed 506 videos remaining 1094
# In Epoch 0 Processed 507 videos remaining 1093
# In Epoch 0 Processed 508 videos remaining 1092
# In Epoch 0 Processed 509 videos remaining 1091
# In Epoch 0 Processed 510 videos remaining 1090
# In Epoch 0 Processed 511 videos remaining 1089
# In Epoch 0 Processed 512 videos remaining 1088
# In Epoch 0 Processed 513 videos remaining 1087
# In Epoch 0 Processed 514 videos remaining 1086
# In Epoch 0 Processed 515 videos remaining 1085
# In Epoch 0 Processed 516 videos remaining 1084
# In Epoch 0 Processed 517 videos remaining 1083
# In Epoch 0 Processed 518 videos remaining 1082
# In Epoch 0 Processed 519 videos remaining 1081
# In Epoch 0 Processed 520 videos remaining 1080
# In Epoch 0 Processed 521 videos remaining 1079
# In Epoch 0 Processed 522 videos remaining 1078
# In Epoch 0 Processed 523 videos remaining 1077
# In Epoch 0 Processed 524 videos remaining 1076
# In Epoch 0 Processed 525 videos remaining 1075
# In Epoch 0 Processed 526 videos remaining 1074
# In Epoch 0 Processed 527 videos remaining 1073
# In Epoch 0 Processed 528 videos remaining 1072
# In Epoch 0 Processed 529 videos remaining 1071
# In Epoch 0 Processed 530 videos remaining 1070
# In Epoch 0 Processed 531 videos remaining 1069
# In Epoch 0 Processed 532 videos remaining 1068
# In Epoch 0 Processed 533 videos remaining 1067
# In Epoch 0 Processed 534 videos remaining 1066
# In Epoch 0 Processed 535 videos remaining 1065
# In Epoch 0 Processed 536 videos remaining 1064
# In Epoch 0 Processed 537 videos remaining 1063
# In Epoch 0 Processed 538 videos remaining 1062
# In Epoch 0 Processed 539 videos remaining 1061
# In Epoch 0 Processed 540 videos remaining 1060
# In Epoch 0 Processed 541 videos remaining 1059
# In Epoch 0 Processed 542 videos remaining 1058
# In Epoch 0 Processed 543 videos remaining 1057
# In Epoch 0 Processed 544 videos remaining 1056
# In Epoch 0 Processed 545 videos remaining 1055
# In Epoch 0 Processed 546 videos remaining 1054
# In Epoch 0 Processed 547 videos remaining 1053
# In Epoch 0 Processed 548 videos remaining 1052
# In Epoch 0 Processed 549 videos remaining 1051
# In Epoch 0 Processed 550 videos remaining 1050
# In Epoch 0 Processed 551 videos remaining 1049
# In Epoch 0 Processed 552 videos remaining 1048
# In Epoch 0 Processed 553 videos remaining 1047
# In Epoch 0 Processed 554 videos remaining 1046
# In Epoch 0 Processed 555 videos remaining 1045
# In Epoch 0 Processed 556 videos remaining 1044
# In Epoch 0 Processed 557 videos remaining 1043
# In Epoch 0 Processed 558 videos remaining 1042
# In Epoch 0 Processed 559 videos remaining 1041
# In Epoch 0 Processed 560 videos remaining 1040
# In Epoch 0 Processed 561 videos remaining 1039
# In Epoch 0 Processed 562 videos remaining 1038
# In Epoch 0 Processed 563 videos remaining 1037
# In Epoch 0 Processed 564 videos remaining 1036
# In Epoch 0 Processed 565 videos remaining 1035
# In Epoch 0 Processed 566 videos remaining 1034
# In Epoch 0 Processed 567 videos remaining 1033
# In Epoch 0 Processed 568 videos remaining 1032
# In Epoch 0 Processed 569 videos remaining 1031
# In Epoch 0 Processed 570 videos remaining 1030
# In Epoch 0 Processed 571 videos remaining 1029
# In Epoch 0 Processed 572 videos remaining 1028
# In Epoch 0 Processed 573 videos remaining 1027
# In Epoch 0 Processed 574 videos remaining 1026
# In Epoch 0 Processed 575 videos remaining 1025
# In Epoch 0 Processed 576 videos remaining 1024
# In Epoch 0 Processed 577 videos remaining 1023
# In Epoch 0 Processed 578 videos remaining 1022
# In Epoch 0 Processed 579 videos remaining 1021
# In Epoch 0 Processed 580 videos remaining 1020
# In Epoch 0 Processed 581 videos remaining 1019
# In Epoch 0 Processed 582 videos remaining 1018
# In Epoch 0 Processed 583 videos remaining 1017
# In Epoch 0 Processed 584 videos remaining 1016
# In Epoch 0 Processed 585 videos remaining 1015
# In Epoch 0 Processed 586 videos remaining 1014
# In Epoch 0 Processed 587 videos remaining 1013
# In Epoch 0 Processed 588 videos remaining 1012
# In Epoch 0 Processed 589 videos remaining 1011
# In Epoch 0 Processed 590 videos remaining 1010
# In Epoch 0 Processed 591 videos remaining 1009
# In Epoch 0 Processed 592 videos remaining 1008
# In Epoch 0 Processed 593 videos remaining 1007
# In Epoch 0 Processed 594 videos remaining 1006
# In Epoch 0 Processed 595 videos remaining 1005
# In Epoch 0 Processed 596 videos remaining 1004
# In Epoch 0 Processed 597 videos remaining 1003
# In Epoch 0 Processed 598 videos remaining 1002
# In Epoch 0 Processed 599 videos remaining 1001
# In Epoch 0 Processed 600 videos remaining 1000
# In Epoch 0 Processed 601 videos remaining 999
# In Epoch 0 Processed 602 videos remaining 998
# In Epoch 0 Processed 603 videos remaining 997
# In Epoch 0 Processed 604 videos remaining 996
# In Epoch 0 Processed 605 videos remaining 995
# In Epoch 0 Processed 606 videos remaining 994
# In Epoch 0 Processed 607 videos remaining 993
# In Epoch 0 Processed 608 videos remaining 992
# In Epoch 0 Processed 609 videos remaining 991
# In Epoch 0 Processed 610 videos remaining 990
# In Epoch 0 Processed 611 videos remaining 989
# In Epoch 0 Processed 612 videos remaining 988
# In Epoch 0 Processed 613 videos remaining 987
# In Epoch 0 Processed 614 videos remaining 986
# In Epoch 0 Processed 615 videos remaining 985
# In Epoch 0 Processed 616 videos remaining 984
# In Epoch 0 Processed 617 videos remaining 983
# In Epoch 0 Processed 618 videos remaining 982
# In Epoch 0 Processed 619 videos remaining 981
# In Epoch 0 Processed 620 videos remaining 980
# In Epoch 0 Processed 621 videos remaining 979
# In Epoch 0 Processed 622 videos remaining 978
# In Epoch 0 Processed 623 videos remaining 977
# In Epoch 0 Processed 624 videos remaining 976
# In Epoch 0 Processed 625 videos remaining 975
# In Epoch 0 Processed 626 videos remaining 974
# In Epoch 0 Processed 627 videos remaining 973
# In Epoch 0 Processed 628 videos remaining 972
# In Epoch 0 Processed 629 videos remaining 971
# In Epoch 0 Processed 630 videos remaining 970
# In Epoch 0 Processed 631 videos remaining 969
# In Epoch 0 Processed 632 videos remaining 968
# In Epoch 0 Processed 633 videos remaining 967
# In Epoch 0 Processed 634 videos remaining 966
# In Epoch 0 Processed 635 videos remaining 965
# In Epoch 0 Processed 636 videos remaining 964
# In Epoch 0 Processed 637 videos remaining 963
# In Epoch 0 Processed 638 videos remaining 962
# In Epoch 0 Processed 639 videos remaining 961
# In Epoch 0 Processed 640 videos remaining 960
# In Epoch 0 Processed 641 videos remaining 959
# In Epoch 0 Processed 642 videos remaining 958
# In Epoch 0 Processed 643 videos remaining 957
# In Epoch 0 Processed 644 videos remaining 956
# In Epoch 0 Processed 645 videos remaining 955
# In Epoch 0 Processed 646 videos remaining 954
# In Epoch 0 Processed 647 videos remaining 953
# In Epoch 0 Processed 648 videos remaining 952
# In Epoch 0 Processed 649 videos remaining 951
# In Epoch 0 Processed 650 videos remaining 950
# In Epoch 0 Processed 651 videos remaining 949
# In Epoch 0 Processed 652 videos remaining 948
# In Epoch 0 Processed 653 videos remaining 947
# In Epoch 0 Processed 654 videos remaining 946
# In Epoch 0 Processed 655 videos remaining 945
# In Epoch 0 Processed 656 videos remaining 944
# In Epoch 0 Processed 657 videos remaining 943
# In Epoch 0 Processed 658 videos remaining 942
# In Epoch 0 Processed 659 videos remaining 941
# In Epoch 0 Processed 660 videos remaining 940
# In Epoch 0 Processed 661 videos remaining 939
# In Epoch 0 Processed 662 videos remaining 938
# In Epoch 0 Processed 663 videos remaining 937
# In Epoch 0 Processed 664 videos remaining 936
# In Epoch 0 Processed 665 videos remaining 935
# In Epoch 0 Processed 666 videos remaining 934
# In Epoch 0 Processed 667 videos remaining 933
# In Epoch 0 Processed 668 videos remaining 932
# In Epoch 0 Processed 669 videos remaining 931
# In Epoch 0 Processed 670 videos remaining 930
# In Epoch 0 Processed 671 videos remaining 929
# In Epoch 0 Processed 672 videos remaining 928
# In Epoch 0 Processed 673 videos remaining 927
# In Epoch 0 Processed 674 videos remaining 926
# In Epoch 0 Processed 675 videos remaining 925
# In Epoch 0 Processed 676 videos remaining 924
# In Epoch 0 Processed 677 videos remaining 923
# In Epoch 0 Processed 678 videos remaining 922
# In Epoch 0 Processed 679 videos remaining 921
# In Epoch 0 Processed 680 videos remaining 920
# In Epoch 0 Processed 681 videos remaining 919
# In Epoch 0 Processed 682 videos remaining 918
# In Epoch 0 Processed 683 videos remaining 917
# In Epoch 0 Processed 684 videos remaining 916
# In Epoch 0 Processed 685 videos remaining 915
# In Epoch 0 Processed 686 videos remaining 914
# In Epoch 0 Processed 687 videos remaining 913
# In Epoch 0 Processed 688 videos remaining 912
# In Epoch 0 Processed 689 videos remaining 911
# In Epoch 0 Processed 690 videos remaining 910
# In Epoch 0 Processed 691 videos remaining 909
# In Epoch 0 Processed 692 videos remaining 908
# In Epoch 0 Processed 693 videos remaining 907
# In Epoch 0 Processed 694 videos remaining 906
# In Epoch 0 Processed 695 videos remaining 905
# In Epoch 0 Processed 696 videos remaining 904
# In Epoch 0 Processed 697 videos remaining 903
# In Epoch 0 Processed 698 videos remaining 902
# In Epoch 0 Processed 699 videos remaining 901
# In Epoch 0 Processed 700 videos remaining 900
# In Epoch 0 Processed 701 videos remaining 899
# In Epoch 0 Processed 702 videos remaining 898
# In Epoch 0 Processed 703 videos remaining 897
# In Epoch 0 Processed 704 videos remaining 896
# In Epoch 0 Processed 705 videos remaining 895
# In Epoch 0 Processed 706 videos remaining 894
# In Epoch 0 Processed 707 videos remaining 893
# In Epoch 0 Processed 708 videos remaining 892
# In Epoch 0 Processed 709 videos remaining 891
# In Epoch 0 Processed 710 videos remaining 890
# In Epoch 0 Processed 711 videos remaining 889
# In Epoch 0 Processed 712 videos remaining 888
# In Epoch 0 Processed 713 videos remaining 887
# In Epoch 0 Processed 714 videos remaining 886
# In Epoch 0 Processed 715 videos remaining 885
# In Epoch 0 Processed 716 videos remaining 884
# In Epoch 0 Processed 717 videos remaining 883
# In Epoch 0 Processed 718 videos remaining 882
# In Epoch 0 Processed 719 videos remaining 881
# In Epoch 0 Processed 720 videos remaining 880
# In Epoch 0 Processed 721 videos remaining 879
# In Epoch 0 Processed 722 videos remaining 878
# In Epoch 0 Processed 723 videos remaining 877
# In Epoch 0 Processed 724 videos remaining 876
# In Epoch 0 Processed 725 videos remaining 875
# In Epoch 0 Processed 726 videos remaining 874
# In Epoch 0 Processed 727 videos remaining 873
# In Epoch 0 Processed 728 videos remaining 872
# In Epoch 0 Processed 729 videos remaining 871
# In Epoch 0 Processed 730 videos remaining 870
# In Epoch 0 Processed 731 videos remaining 869
# In Epoch 0 Processed 732 videos remaining 868
# In Epoch 0 Processed 733 videos remaining 867
# In Epoch 0 Processed 734 videos remaining 866
# In Epoch 0 Processed 735 videos remaining 865
# In Epoch 0 Processed 736 videos remaining 864
# In Epoch 0 Processed 737 videos remaining 863
# In Epoch 0 Processed 738 videos remaining 862
# In Epoch 0 Processed 739 videos remaining 861
# In Epoch 0 Processed 740 videos remaining 860
# In Epoch 0 Processed 741 videos remaining 859
# In Epoch 0 Processed 742 videos remaining 858
# In Epoch 0 Processed 743 videos remaining 857
# In Epoch 0 Processed 744 videos remaining 856
# In Epoch 0 Processed 745 videos remaining 855
# In Epoch 0 Processed 746 videos remaining 854
# In Epoch 0 Processed 747 videos remaining 853
# In Epoch 0 Processed 748 videos remaining 852
# In Epoch 0 Processed 749 videos remaining 851
# In Epoch 0 Processed 750 videos remaining 850
# In Epoch 0 Processed 751 videos remaining 849
# In Epoch 0 Processed 752 videos remaining 848
# In Epoch 0 Processed 753 videos remaining 847
# In Epoch 0 Processed 754 videos remaining 846
# In Epoch 0 Processed 755 videos remaining 845
# In Epoch 0 Processed 756 videos remaining 844
# In Epoch 0 Processed 757 videos remaining 843
# In Epoch 0 Processed 758 videos remaining 842
# In Epoch 0 Processed 759 videos remaining 841
# In Epoch 0 Processed 760 videos remaining 840
# In Epoch 0 Processed 761 videos remaining 839
# In Epoch 0 Processed 762 videos remaining 838
# In Epoch 0 Processed 763 videos remaining 837
# In Epoch 0 Processed 764 videos remaining 836
# In Epoch 0 Processed 765 videos remaining 835
# In Epoch 0 Processed 766 videos remaining 834
# In Epoch 0 Processed 767 videos remaining 833
# In Epoch 0 Processed 768 videos remaining 832
# In Epoch 0 Processed 769 videos remaining 831
# In Epoch 0 Processed 770 videos remaining 830
# In Epoch 0 Processed 771 videos remaining 829
# In Epoch 0 Processed 772 videos remaining 828
# In Epoch 0 Processed 773 videos remaining 827
# In Epoch 0 Processed 774 videos remaining 826
# In Epoch 0 Processed 775 videos remaining 825
# In Epoch 0 Processed 776 videos remaining 824
# In Epoch 0 Processed 777 videos remaining 823
# In Epoch 0 Processed 778 videos remaining 822
# In Epoch 0 Processed 779 videos remaining 821
# In Epoch 0 Processed 780 videos remaining 820
# In Epoch 0 Processed 781 videos remaining 819
# In Epoch 0 Processed 782 videos remaining 818
# In Epoch 0 Processed 783 videos remaining 817
# In Epoch 0 Processed 784 videos remaining 816
# In Epoch 0 Processed 785 videos remaining 815
# In Epoch 0 Processed 786 videos remaining 814
# In Epoch 0 Processed 787 videos remaining 813
# In Epoch 0 Processed 788 videos remaining 812
# In Epoch 0 Processed 789 videos remaining 811
# In Epoch 0 Processed 790 videos remaining 810
# In Epoch 0 Processed 791 videos remaining 809
# In Epoch 0 Processed 792 videos remaining 808
# In Epoch 0 Processed 793 videos remaining 807
# In Epoch 0 Processed 794 videos remaining 806
# In Epoch 0 Processed 795 videos remaining 805
# In Epoch 0 Processed 796 videos remaining 804
# In Epoch 0 Processed 797 videos remaining 803
# In Epoch 0 Processed 798 videos remaining 802
# In Epoch 0 Processed 799 videos remaining 801
# In Epoch 0 Processed 800 videos remaining 800
# In Epoch 0 Processed 801 videos remaining 799
# In Epoch 0 Processed 802 videos remaining 798
# In Epoch 0 Processed 803 videos remaining 797
# In Epoch 0 Processed 804 videos remaining 796
# In Epoch 0 Processed 805 videos remaining 795
# In Epoch 0 Processed 806 videos remaining 794
# In Epoch 0 Processed 807 videos remaining 793
# In Epoch 0 Processed 808 videos remaining 792
# In Epoch 0 Processed 809 videos remaining 791
# In Epoch 0 Processed 810 videos remaining 790
# In Epoch 0 Processed 811 videos remaining 789
# In Epoch 0 Processed 812 videos remaining 788
# In Epoch 0 Processed 813 videos remaining 787
# In Epoch 0 Processed 814 videos remaining 786
# In Epoch 0 Processed 815 videos remaining 785
# In Epoch 0 Processed 816 videos remaining 784
# In Epoch 0 Processed 817 videos remaining 783
# In Epoch 0 Processed 818 videos remaining 782
# In Epoch 0 Processed 819 videos remaining 781
# In Epoch 0 Processed 820 videos remaining 780
# In Epoch 0 Processed 821 videos remaining 779
# In Epoch 0 Processed 822 videos remaining 778
# In Epoch 0 Processed 823 videos remaining 777
# In Epoch 0 Processed 824 videos remaining 776
# In Epoch 0 Processed 825 videos remaining 775
# In Epoch 0 Processed 826 videos remaining 774
# In Epoch 0 Processed 827 videos remaining 773
# In Epoch 0 Processed 828 videos remaining 772
# In Epoch 0 Processed 829 videos remaining 771
# In Epoch 0 Processed 830 videos remaining 770
# In Epoch 0 Processed 831 videos remaining 769
# In Epoch 0 Processed 832 videos remaining 768
# In Epoch 0 Processed 833 videos remaining 767
# In Epoch 0 Processed 834 videos remaining 766
# In Epoch 0 Processed 835 videos remaining 765
# In Epoch 0 Processed 836 videos remaining 764
# In Epoch 0 Processed 837 videos remaining 763
# In Epoch 0 Processed 838 videos remaining 762
# In Epoch 0 Processed 839 videos remaining 761
# In Epoch 0 Processed 840 videos remaining 760
# In Epoch 0 Processed 841 videos remaining 759
# In Epoch 0 Processed 842 videos remaining 758
# In Epoch 0 Processed 843 videos remaining 757
# In Epoch 0 Processed 844 videos remaining 756
# In Epoch 0 Processed 845 videos remaining 755
# In Epoch 0 Processed 846 videos remaining 754
# In Epoch 0 Processed 847 videos remaining 753
# In Epoch 0 Processed 848 videos remaining 752
# In Epoch 0 Processed 849 videos remaining 751
# In Epoch 0 Processed 850 videos remaining 750
# In Epoch 0 Processed 851 videos remaining 749
# In Epoch 0 Processed 852 videos remaining 748
# In Epoch 0 Processed 853 videos remaining 747
# In Epoch 0 Processed 854 videos remaining 746
# In Epoch 0 Processed 855 videos remaining 745
# In Epoch 0 Processed 856 videos remaining 744
# In Epoch 0 Processed 857 videos remaining 743
# In Epoch 0 Processed 858 videos remaining 742
# In Epoch 0 Processed 859 videos remaining 741
# In Epoch 0 Processed 860 videos remaining 740
# In Epoch 0 Processed 861 videos remaining 739
# In Epoch 0 Processed 862 videos remaining 738
# In Epoch 0 Processed 863 videos remaining 737
# In Epoch 0 Processed 864 videos remaining 736
# In Epoch 0 Processed 865 videos remaining 735
# In Epoch 0 Processed 866 videos remaining 734
# In Epoch 0 Processed 867 videos remaining 733
# In Epoch 0 Processed 868 videos remaining 732
# In Epoch 0 Processed 869 videos remaining 731
# In Epoch 0 Processed 870 videos remaining 730
# In Epoch 0 Processed 871 videos remaining 729
# In Epoch 0 Processed 872 videos remaining 728
# In Epoch 0 Processed 873 videos remaining 727
# In Epoch 0 Processed 874 videos remaining 726
# In Epoch 0 Processed 875 videos remaining 725
# In Epoch 0 Processed 876 videos remaining 724
# In Epoch 0 Processed 877 videos remaining 723
# In Epoch 0 Processed 878 videos remaining 722
# In Epoch 0 Processed 879 videos remaining 721
# In Epoch 0 Processed 880 videos remaining 720
# In Epoch 0 Processed 881 videos remaining 719
# In Epoch 0 Processed 882 videos remaining 718
# In Epoch 0 Processed 883 videos remaining 717
# In Epoch 0 Processed 884 videos remaining 716
# In Epoch 0 Processed 885 videos remaining 715
# In Epoch 0 Processed 886 videos remaining 714
# In Epoch 0 Processed 887 videos remaining 713
# In Epoch 0 Processed 888 videos remaining 712
# In Epoch 0 Processed 889 videos remaining 711
# In Epoch 0 Processed 890 videos remaining 710
# In Epoch 0 Processed 891 videos remaining 709
# In Epoch 0 Processed 892 videos remaining 708
# In Epoch 0 Processed 893 videos remaining 707
# In Epoch 0 Processed 894 videos remaining 706
# In Epoch 0 Processed 895 videos remaining 705
# In Epoch 0 Processed 896 videos remaining 704
# In Epoch 0 Processed 897 videos remaining 703
# In Epoch 0 Processed 898 videos remaining 702
# In Epoch 0 Processed 899 videos remaining 701
# In Epoch 0 Processed 900 videos remaining 700
# In Epoch 0 Processed 901 videos remaining 699
# In Epoch 0 Processed 902 videos remaining 698
# In Epoch 0 Processed 903 videos remaining 697
# In Epoch 0 Processed 904 videos remaining 696
# In Epoch 0 Processed 905 videos remaining 695
# In Epoch 0 Processed 906 videos remaining 694
# In Epoch 0 Processed 907 videos remaining 693
# In Epoch 0 Processed 908 videos remaining 692
# In Epoch 0 Processed 909 videos remaining 691
# In Epoch 0 Processed 910 videos remaining 690
# In Epoch 0 Processed 911 videos remaining 689
# In Epoch 0 Processed 912 videos remaining 688
# In Epoch 0 Processed 913 videos remaining 687
# In Epoch 0 Processed 914 videos remaining 686
# In Epoch 0 Processed 915 videos remaining 685
# In Epoch 0 Processed 916 videos remaining 684
# In Epoch 0 Processed 917 videos remaining 683
# In Epoch 0 Processed 918 videos remaining 682
# In Epoch 0 Processed 919 videos remaining 681
# In Epoch 0 Processed 920 videos remaining 680
# In Epoch 0 Processed 921 videos remaining 679
# In Epoch 0 Processed 922 videos remaining 678
# In Epoch 0 Processed 923 videos remaining 677
# In Epoch 0 Processed 924 videos remaining 676
# In Epoch 0 Processed 925 videos remaining 675
# In Epoch 0 Processed 926 videos remaining 674
# In Epoch 0 Processed 927 videos remaining 673
# In Epoch 0 Processed 928 videos remaining 672
# In Epoch 0 Processed 929 videos remaining 671
# In Epoch 0 Processed 930 videos remaining 670
# In Epoch 0 Processed 931 videos remaining 669
# In Epoch 0 Processed 932 videos remaining 668
# In Epoch 0 Processed 933 videos remaining 667
# In Epoch 0 Processed 934 videos remaining 666
# In Epoch 0 Processed 935 videos remaining 665
# In Epoch 0 Processed 936 videos remaining 664
# In Epoch 0 Processed 937 videos remaining 663
# In Epoch 0 Processed 938 videos remaining 662
# In Epoch 0 Processed 939 videos remaining 661
# In Epoch 0 Processed 940 videos remaining 660
# In Epoch 0 Processed 941 videos remaining 659
# In Epoch 0 Processed 942 videos remaining 658
# In Epoch 0 Processed 943 videos remaining 657
# In Epoch 0 Processed 944 videos remaining 656
# In Epoch 0 Processed 945 videos remaining 655
# In Epoch 0 Processed 946 videos remaining 654
# In Epoch 0 Processed 947 videos remaining 653
# In Epoch 0 Processed 948 videos remaining 652
# In Epoch 0 Processed 949 videos remaining 651
# In Epoch 0 Processed 950 videos remaining 650
# In Epoch 0 Processed 951 videos remaining 649
# In Epoch 0 Processed 952 videos remaining 648
# In Epoch 0 Processed 953 videos remaining 647
# In Epoch 0 Processed 954 videos remaining 646
# In Epoch 0 Processed 955 videos remaining 645
# In Epoch 0 Processed 956 videos remaining 644
# In Epoch 0 Processed 957 videos remaining 643
# In Epoch 0 Processed 958 videos remaining 642
# In Epoch 0 Processed 959 videos remaining 641
# In Epoch 0 Processed 960 videos remaining 640
# In Epoch 0 Processed 961 videos remaining 639
# In Epoch 0 Processed 962 videos remaining 638
# In Epoch 0 Processed 963 videos remaining 637
# In Epoch 0 Processed 964 videos remaining 636
# In Epoch 0 Processed 965 videos remaining 635
# In Epoch 0 Processed 966 videos remaining 634
# In Epoch 0 Processed 967 videos remaining 633
# In Epoch 0 Processed 968 videos remaining 632
# In Epoch 0 Processed 969 videos remaining 631
# In Epoch 0 Processed 970 videos remaining 630
# In Epoch 0 Processed 971 videos remaining 629
# In Epoch 0 Processed 972 videos remaining 628
# In Epoch 0 Processed 973 videos remaining 627
# In Epoch 0 Processed 974 videos remaining 626
# In Epoch 0 Processed 975 videos remaining 625
# In Epoch 0 Processed 976 videos remaining 624
# In Epoch 0 Processed 977 videos remaining 623
# In Epoch 0 Processed 978 videos remaining 622
# In Epoch 0 Processed 979 videos remaining 621
# In Epoch 0 Processed 980 videos remaining 620
# In Epoch 0 Processed 981 videos remaining 619
# In Epoch 0 Processed 982 videos remaining 618
# In Epoch 0 Processed 983 videos remaining 617
# In Epoch 0 Processed 984 videos remaining 616
# In Epoch 0 Processed 985 videos remaining 615
# In Epoch 0 Processed 986 videos remaining 614
# In Epoch 0 Processed 987 videos remaining 613
# In Epoch 0 Processed 988 videos remaining 612
# In Epoch 0 Processed 989 videos remaining 611
# In Epoch 0 Processed 990 videos remaining 610
# In Epoch 0 Processed 991 videos remaining 609
# In Epoch 0 Processed 992 videos remaining 608
# In Epoch 0 Processed 993 videos remaining 607
# In Epoch 0 Processed 994 videos remaining 606
# In Epoch 0 Processed 995 videos remaining 605
# In Epoch 0 Processed 996 videos remaining 604
# In Epoch 0 Processed 997 videos remaining 603
# In Epoch 0 Processed 998 videos remaining 602
# In Epoch 0 Processed 999 videos remaining 601
# In Epoch 0 Processed 1000 videos remaining 600
# In Epoch 0 Processed 1001 videos remaining 599
# In Epoch 0 Processed 1002 videos remaining 598
# In Epoch 0 Processed 1003 videos remaining 597
# In Epoch 0 Processed 1004 videos remaining 596
# In Epoch 0 Processed 1005 videos remaining 595
# In Epoch 0 Processed 1006 videos remaining 594
# In Epoch 0 Processed 1007 videos remaining 593
# In Epoch 0 Processed 1008 videos remaining 592
# In Epoch 0 Processed 1009 videos remaining 591
# In Epoch 0 Processed 1010 videos remaining 590
# In Epoch 0 Processed 1011 videos remaining 589
# In Epoch 0 Processed 1012 videos remaining 588
# In Epoch 0 Processed 1013 videos remaining 587
# In Epoch 0 Processed 1014 videos remaining 586
# In Epoch 0 Processed 1015 videos remaining 585
# In Epoch 0 Processed 1016 videos remaining 584
# In Epoch 0 Processed 1017 videos remaining 583
# In Epoch 0 Processed 1018 videos remaining 582
# In Epoch 0 Processed 1019 videos remaining 581
# In Epoch 0 Processed 1020 videos remaining 580
# In Epoch 0 Processed 1021 videos remaining 579
# ...
# In Epoch 12 Processed 1561 videos remaining 39
# In Epoch 12 Processed 1562 videos remaining 38
# In Epoch 12 Processed 1563 videos remaining 37
# In Epoch 12 Processed 1564 videos remaining 36
# In Epoch 12 Processed 1565 videos remaining 35
# In Epoch 12 Processed 1566 videos remaining 34
# In Epoch 12 Processed 1567 videos remaining 33
# In Epoch 12 Processed 1568 videos remaining 32
# In Epoch 12 Processed 1569 videos remaining 31
# In Epoch 12 Processed 1570 videos remaining 30
# In Epoch 12 Processed 1571 videos remaining 29
# In Epoch 12 Processed 1572 videos remaining 28
# In Epoch 12 Processed 1573 videos remaining 27
# In Epoch 12 Processed 1574 videos remaining 26
# In Epoch 12 Processed 1575 videos remaining 25
# In Epoch 12 Processed 1576 videos remaining 24
# In Epoch 12 Processed 1577 videos remaining 23
# In Epoch 12 Processed 1578 videos remaining 22
# In Epoch 12 Processed 1579 videos remaining 21
# In Epoch 12 Processed 1580 videos remaining 20
# In Epoch 12 Processed 1581 videos remaining 19
# In Epoch 12 Processed 1582 videos remaining 18
# In Epoch 12 Processed 1583 videos remaining 17
# In Epoch 12 Processed 1584 videos remaining 16
# In Epoch 12 Processed 1585 videos remaining 15
# In Epoch 12 Processed 1586 videos remaining 14
# In Epoch 12 Processed 1587 videos remaining 13
# In Epoch 12 Processed 1588 videos remaining 12
# In Epoch 12 Processed 1589 videos remaining 11
# In Epoch 12 Processed 1590 videos remaining 10
# In Epoch 12 Processed 1591 videos remaining 9
# In Epoch 12 Processed 1592 videos remaining 8
# In Epoch 12 Processed 1593 videos remaining 7
# In Epoch 12 Processed 1594 videos remaining 6
# In Epoch 12 Processed 1595 videos remaining 5
# In Epoch 12 Processed 1596 videos remaining 4
# In Epoch 12 Processed 1597 videos remaining 3
# In Epoch 12 Processed 1598 videos remaining 2
# In Epoch 12 Processed 1599 videos remaining 1
# In Epoch 12 Processed 1600 videos remaining 0
# Validating The Model....
#
# ✅ Validation Loss: 0.3371 | Accuracy: 90.06%
#
# 📊 Classification Report (Epoch 12):
#                        precision    recall  f1-score   support
#
#                 Abuse       1.00      0.98      0.99        50
#             Explosion       0.92      0.94      0.93        50
#              Fighting       0.86      0.86      0.86        50
#         RoadAccidents       0.90      0.86      0.88        50
#               Robbery       0.91      0.82      0.86        50
#              Shooting       0.17      1.00      0.29         2
#             Vandalism       0.96      0.88      0.92        50
# z_Normal_Videos_event       0.94      0.96      0.95        50
#
#              accuracy                           0.90       352
#             macro avg       0.83      0.91      0.83       352
#          weighted avg       0.92      0.90      0.91       352
#
#
# 📦 Epoch [13/50] Summary:
# 🔺 Train Loss: 0.1561 | Train Time: 1436.97s
# 🔹 Val Loss  : 0.3371 | Accuracy: 90.06%
# ⏱ Epoch Time: 2176.33s | Estimated Time Remaining: 51688.62s
# In Epoch 13 Processed 1 videos remaining 1599
# In Epoch 13 Processed 2 videos remaining 1598
# In Epoch 13 Processed 3 videos remaining 1597
# In Epoch 13 Processed 4 videos remaining 1596
# In Epoch 13 Processed 5 videos remaining 1595
# In Epoch 13 Processed 6 videos remaining 1594
# In Epoch 13 Processed 7 videos remaining 1593
# In Epoch 13 Processed 8 videos remaining 1592
# In Epoch 13 Processed 9 videos remaining 1591
# In Epoch 13 Processed 10 videos remaining 1590
# In Epoch 13 Processed 11 videos remaining 1589
# In Epoch 13 Processed 12 videos remaining 1588
# In Epoch 13 Processed 13 videos remaining 1587
# In Epoch 13 Processed 14 videos remaining 1586
# In Epoch 13 Processed 15 videos remaining 1585
# In Epoch 13 Processed 16 videos remaining 1584
# In Epoch 13 Processed 17 videos remaining 1583
# In Epoch 13 Processed 18 videos remaining 1582
# In Epoch 13 Processed 19 videos remaining 1581
# In Epoch 13 Processed 20 videos remaining 1580
# In Epoch 13 Processed 21 videos remaining 1579
# In Epoch 13 Processed 22 videos remaining 1578
# In Epoch 13 Processed 23 videos remaining 1577
# In Epoch 13 Processed 24 videos remaining 1576
# In Epoch 13 Processed 25 videos remaining 1575
# In Epoch 13 Processed 26 videos remaining 1574
# In Epoch 13 Processed 27 videos remaining 1573
# In Epoch 13 Processed 28 videos remaining 1572
# In Epoch 13 Processed 29 videos remaining 1571
# In Epoch 13 Processed 30 videos remaining 1570
# In Epoch 13 Processed 31 videos remaining 1569
# In Epoch 13 Processed 32 videos remaining 1568
# In Epoch 13 Processed 33 videos remaining 1567
# In Epoch 13 Processed 34 videos remaining 1566
# In Epoch 13 Processed 35 videos remaining 1565
# In Epoch 13 Processed 36 videos remaining 1564
# In Epoch 13 Processed 37 videos remaining 1563
# In Epoch 13 Processed 38 videos remaining 1562
# In Epoch 13 Processed 39 videos remaining 1561
# In Epoch 13 Processed 40 videos remaining 1560
# In Epoch 13 Processed 41 videos remaining 1559
# In Epoch 13 Processed 42 videos remaining 1558
# In Epoch 13 Processed 43 videos remaining 1557
# In Epoch 13 Processed 44 videos remaining 1556
# In Epoch 13 Processed 45 videos remaining 1555
# In Epoch 13 Processed 46 videos remaining 1554
# In Epoch 13 Processed 47 videos remaining 1553
# In Epoch 13 Processed 48 videos remaining 1552
# In Epoch 13 Processed 49 videos remaining 1551
# In Epoch 13 Processed 50 videos remaining 1550
# In Epoch 13 Processed 51 videos remaining 1549
# In Epoch 13 Processed 52 videos remaining 1548
# In Epoch 13 Processed 53 videos remaining 1547
# In Epoch 13 Processed 54 videos remaining 1546
# In Epoch 13 Processed 55 videos remaining 1545
# In Epoch 13 Processed 56 videos remaining 1544
# In Epoch 13 Processed 57 videos remaining 1543
# In Epoch 13 Processed 58 videos remaining 1542
# In Epoch 13 Processed 59 videos remaining 1541
# In Epoch 13 Processed 60 videos remaining 1540
# In Epoch 13 Processed 61 videos remaining 1539
# In Epoch 13 Processed 62 videos remaining 1538
# In Epoch 13 Processed 63 videos remaining 1537
# In Epoch 13 Processed 64 videos remaining 1536
# In Epoch 13 Processed 65 videos remaining 1535
# In Epoch 13 Processed 66 videos remaining 1534
# In Epoch 13 Processed 67 videos remaining 1533
# In Epoch 13 Processed 68 videos remaining 1532
# In Epoch 13 Processed 69 videos remaining 1531
# In Epoch 13 Processed 70 videos remaining 1530
# In Epoch 13 Processed 71 videos remaining 1529
# In Epoch 13 Processed 72 videos remaining 1528
# In Epoch 13 Processed 73 videos remaining 1527
# In Epoch 13 Processed 74 videos remaining 1526
# In Epoch 13 Processed 75 videos remaining 1525
# In Epoch 13 Processed 76 videos remaining 1524
# In Epoch 13 Processed 77 videos remaining 1523
# In Epoch 13 Processed 78 videos remaining 1522
# In Epoch 13 Processed 79 videos remaining 1521
# In Epoch 13 Processed 80 videos remaining 1520
# In Epoch 13 Processed 81 videos remaining 1519
# In Epoch 13 Processed 82 videos remaining 1518
# In Epoch 13 Processed 83 videos remaining 1517
# In Epoch 13 Processed 84 videos remaining 1516
# In Epoch 13 Processed 85 videos remaining 1515
# In Epoch 13 Processed 86 videos remaining 1514
# In Epoch 13 Processed 87 videos remaining 1513
# In Epoch 13 Processed 88 videos remaining 1512
# In Epoch 13 Processed 89 videos remaining 1511
# In Epoch 13 Processed 90 videos remaining 1510
# In Epoch 13 Processed 91 videos remaining 1509
# In Epoch 13 Processed 92 videos remaining 1508
# In Epoch 13 Processed 93 videos remaining 1507
# In Epoch 13 Processed 94 videos remaining 1506
# In Epoch 13 Processed 95 videos remaining 1505
# In Epoch 13 Processed 96 videos remaining 1504
# In Epoch 13 Processed 97 videos remaining 1503
# In Epoch 13 Processed 98 videos remaining 1502
# In Epoch 13 Processed 99 videos remaining 1501
# In Epoch 13 Processed 100 videos remaining 1500
# In Epoch 13 Processed 101 videos remaining 1499
# In Epoch 13 Processed 102 videos remaining 1498
# In Epoch 13 Processed 103 videos remaining 1497
# In Epoch 13 Processed 104 videos remaining 1496
# In Epoch 13 Processed 105 videos remaining 1495
# In Epoch 13 Processed 106 videos remaining 1494
# In Epoch 13 Processed 107 videos remaining 1493
# In Epoch 13 Processed 108 videos remaining 1492
# In Epoch 13 Processed 109 videos remaining 1491
# In Epoch 13 Processed 110 videos remaining 1490
# In Epoch 13 Processed 111 videos remaining 1489
# In Epoch 13 Processed 112 videos remaining 1488
# In Epoch 13 Processed 113 videos remaining 1487
# In Epoch 13 Processed 114 videos remaining 1486
# In Epoch 13 Processed 115 videos remaining 1485
# In Epoch 13 Processed 116 videos remaining 1484
# In Epoch 13 Processed 117 videos remaining 1483
# In Epoch 13 Processed 118 videos remaining 1482
# In Epoch 13 Processed 119 videos remaining 1481
# In Epoch 13 Processed 120 videos remaining 1480
# In Epoch 13 Processed 121 videos remaining 1479
# In Epoch 13 Processed 122 videos remaining 1478
# In Epoch 13 Processed 123 videos remaining 1477
# In Epoch 13 Processed 124 videos remaining 1476
# In Epoch 13 Processed 125 videos remaining 1475
# In Epoch 13 Processed 126 videos remaining 1474
# In Epoch 13 Processed 127 videos remaining 1473
# In Epoch 13 Processed 128 videos remaining 1472
# In Epoch 13 Processed 129 videos remaining 1471
# In Epoch 13 Processed 130 videos remaining 1470
# In Epoch 13 Processed 131 videos remaining 1469
# In Epoch 13 Processed 132 videos remaining 1468
# In Epoch 13 Processed 133 videos remaining 1467
# In Epoch 13 Processed 134 videos remaining 1466
# In Epoch 13 Processed 135 videos remaining 1465
# In Epoch 13 Processed 136 videos remaining 1464
# In Epoch 13 Processed 137 videos remaining 1463
# In Epoch 13 Processed 138 videos remaining 1462
# In Epoch 13 Processed 139 videos remaining 1461
# In Epoch 13 Processed 140 videos remaining 1460
# In Epoch 13 Processed 141 videos remaining 1459
# In Epoch 13 Processed 142 videos remaining 1458
# In Epoch 13 Processed 143 videos remaining 1457
# In Epoch 13 Processed 144 videos remaining 1456
# In Epoch 13 Processed 145 videos remaining 1455
# In Epoch 13 Processed 146 videos remaining 1454
# In Epoch 13 Processed 147 videos remaining 1453
# In Epoch 13 Processed 148 videos remaining 1452
# In Epoch 13 Processed 149 videos remaining 1451
# In Epoch 13 Processed 150 videos remaining 1450
# In Epoch 13 Processed 151 videos remaining 1449
# In Epoch 13 Processed 152 videos remaining 1448
# In Epoch 13 Processed 153 videos remaining 1447
# In Epoch 13 Processed 154 videos remaining 1446
# In Epoch 13 Processed 155 videos remaining 1445
# In Epoch 13 Processed 156 videos remaining 1444
# In Epoch 13 Processed 157 videos remaining 1443
# In Epoch 13 Processed 158 videos remaining 1442
# In Epoch 13 Processed 159 videos remaining 1441
# In Epoch 13 Processed 160 videos remaining 1440
# In Epoch 13 Processed 161 videos remaining 1439
# In Epoch 13 Processed 162 videos remaining 1438
# In Epoch 13 Processed 163 videos remaining 1437
# In Epoch 13 Processed 164 videos remaining 1436
# In Epoch 13 Processed 165 videos remaining 1435
# In Epoch 13 Processed 166 videos remaining 1434
# In Epoch 13 Processed 167 videos remaining 1433
# In Epoch 13 Processed 168 videos remaining 1432
# In Epoch 13 Processed 169 videos remaining 1431
# In Epoch 13 Processed 170 videos remaining 1430
# In Epoch 13 Processed 171 videos remaining 1429
# In Epoch 13 Processed 172 videos remaining 1428
# In Epoch 13 Processed 173 videos remaining 1427
# In Epoch 13 Processed 174 videos remaining 1426
# In Epoch 13 Processed 175 videos remaining 1425
# In Epoch 13 Processed 176 videos remaining 1424
# In Epoch 13 Processed 177 videos remaining 1423
# In Epoch 13 Processed 178 videos remaining 1422
# In Epoch 13 Processed 179 videos remaining 1421
# In Epoch 13 Processed 180 videos remaining 1420
# In Epoch 13 Processed 181 videos remaining 1419
# In Epoch 13 Processed 182 videos remaining 1418
# In Epoch 13 Processed 183 videos remaining 1417
# In Epoch 13 Processed 184 videos remaining 1416
# In Epoch 13 Processed 185 videos remaining 1415
# In Epoch 13 Processed 186 videos remaining 1414
# In Epoch 13 Processed 187 videos remaining 1413
# In Epoch 13 Processed 188 videos remaining 1412
# In Epoch 13 Processed 189 videos remaining 1411
# In Epoch 13 Processed 190 videos remaining 1410
# In Epoch 13 Processed 191 videos remaining 1409
# In Epoch 13 Processed 192 videos remaining 1408
# In Epoch 13 Processed 193 videos remaining 1407
# In Epoch 13 Processed 194 videos remaining 1406
# In Epoch 13 Processed 195 videos remaining 1405
# In Epoch 13 Processed 196 videos remaining 1404
# In Epoch 13 Processed 197 videos remaining 1403
# In Epoch 13 Processed 198 videos remaining 1402
# In Epoch 13 Processed 199 videos remaining 1401
# In Epoch 13 Processed 200 videos remaining 1400
# In Epoch 13 Processed 201 videos remaining 1399
# In Epoch 13 Processed 202 videos remaining 1398
# In Epoch 13 Processed 203 videos remaining 1397
# In Epoch 13 Processed 204 videos remaining 1396
# In Epoch 13 Processed 205 videos remaining 1395
# In Epoch 13 Processed 206 videos remaining 1394
# In Epoch 13 Processed 207 videos remaining 1393
# In Epoch 13 Processed 208 videos remaining 1392
# In Epoch 13 Processed 209 videos remaining 1391
# In Epoch 13 Processed 210 videos remaining 1390
# In Epoch 13 Processed 211 videos remaining 1389
# In Epoch 13 Processed 212 videos remaining 1388
# In Epoch 13 Processed 213 videos remaining 1387
# In Epoch 13 Processed 214 videos remaining 1386
# In Epoch 13 Processed 215 videos remaining 1385
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 301
#     298     print(f"Partially fine-tuned model saved to {save_path}")
#     300 if __name__ == "__main__":
# --> 301     main()
#
# Cell In[1], line 282, in main()
#     279 val_loader = get_data_loader(VAL_DIR, batch_size=BATCH_SIZE, clip_len=96, shuffle=False)
#     281 # Train the model partially (only the classifier head will be updated)
# --> 282 train_partial(
#     283     model,
#     284     train_loader,
#     285     val_loader,
#     286     device,
#     287     epochs=NUM_EPOCHS,
#     288     lr=LEARNING_RATE,
#     289     target_accuracy=96.0,
#     290     checkpoint_dir="data/trained_models/checkpoints",
#     291     log_dir="runs/TimeSformer",
#     292     class_list=CLASS_NAMES
#     293 )
#     295 # Save the final fine-tuned model
#     296 save_path = r"data\trained_models\timesformer_partial_finetuned.pth"
#
# Cell In[1], line 201, in train_partial(model, train_loader, val_loader, device, epochs, lr, target_accuracy, checkpoint_dir, log_dir, class_list)
#     199     loss = criterion(outputs, labels)
#     200 scaler.scale(loss).backward()
# --> 201 scaler.step(optimizer)
#     202 scaler.update()
#     203 running_loss += loss.item()
#
# File c:\Users\jashw\Desktop\Video Surveillance\venv\Lib\site-packages\torch\amp\grad_scaler.py:457, in GradScaler.step(self, optimizer, *args, **kwargs)
#     451     self.unscale_(optimizer)
#     453 assert (
#     454     len(optimizer_state["found_inf_per_device"]) > 0
#     455 ), "No inf checks were recorded for this optimizer."
# --> 457 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     459 optimizer_state["stage"] = OptState.STEPPED
#     461 return retval
#
# File c:\Users\jashw\Desktop\Video Surveillance\venv\Lib\site-packages\torch\amp\grad_scaler.py:351, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     343 def _maybe_opt_step(
#     344     self,
#     345     optimizer: torch.optim.Optimizer,
#    (...)    348     **kwargs: Any,
#     349 ) -> Optional[float]:
#     350     retval: Optional[float] = None
# --> 351     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     352         retval = optimizer.step(*args, **kwargs)
#     353     return retval
#
# File c:\Users\jashw\Desktop\Video Surveillance\venv\Lib\site-packages\torch\amp\grad_scaler.py:351, in <genexpr>(.0)
#     343 def _maybe_opt_step(
#     344     self,
#     345     optimizer: torch.optim.Optimizer,
#    (...)    348     **kwargs: Any,
#     349 ) -> Optional[float]:
#     350     retval: Optional[float] = None
# --> 351     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     352         retval = optimizer.step(*args, **kwargs)
#     353     return retval
#
# KeyboardInterrupt:

# %%
# Out:
# 5
